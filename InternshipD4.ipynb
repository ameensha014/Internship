# %% [markdown]
# <a href="https://colab.research.google.com/github/ameensha014/Internship/blob/Day-4/InternshipD4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv(r'/content/sample_data/beer-servings (2) (1).csv',index_col='Unnamed: 0')

# %%
data
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan            0.0              0.0            0.0
# 1        Albania           89.0            132.0           54.0
# 2        Algeria           25.0              0.0           14.0
# 3        Andorra          245.0            138.0          312.0
# 4         Angola          217.0             57.0           45.0
# ..           ...            ...              ...            ...
# 188    Venezuela            NaN            100.0            3.0
# 189      Vietnam          111.0              2.0            1.0
# 190        Yemen            6.0              0.0            0.0
# 191       Zambia           32.0             19.0            4.0
# 192     Zimbabwe           64.0             18.0            4.0
#
#      total_litres_of_pure_alcohol      continent
# 0                             0.0           Asia
# 1                             4.9         Europe
# ...

# %%
data.isna().sum()
# Out:
# country                         0
# beer_servings                   8
# spirit_servings                 8
# wine_servings                   6
# total_litres_of_pure_alcohol    1
# continent                       0
# dtype: int64

# %%
for i in ['beer_servings', 'spirit_servings', 'wine_servings','total_litres_of_pure_alcohol']:
  data[i]=data[i].fillna(data[i].median())

# %%
data.isna().sum()
# Out:
# country                         0
# beer_servings                   0
# spirit_servings                 0
# wine_servings                   0
# total_litres_of_pure_alcohol    0
# continent                       0
# dtype: int64

# %%
data.shape
# Out:
# (193, 6)

# %%
data.dtypes
# Out:
# country                          object
# beer_servings                   float64
# spirit_servings                 float64
# wine_servings                   float64
# total_litres_of_pure_alcohol    float64
# continent                        object
# dtype: object

# %%
data.continent.nunique()
# Out:
# 6

# %%
data1=pd.get_dummies(data)

# %%
data1.shape
# Out:
# (193, 203)

# %%
data1
# Out:
#      beer_servings  spirit_servings  wine_servings  \
# 0              0.0              0.0            0.0
# 1             89.0            132.0           54.0
# 2             25.0              0.0           14.0
# 3            245.0            138.0          312.0
# 4            217.0             57.0           45.0
# ..             ...              ...            ...
# 188           76.0            100.0            3.0
# 189          111.0              2.0            1.0
# 190            6.0              0.0            0.0
# 191           32.0             19.0            4.0
# 192           64.0             18.0            4.0
#
#      total_litres_of_pure_alcohol  country_Afghanistan  country_Albania  \
# 0                             0.0                    1                0
# 1                             4.9                    0                1
# 2                             0.7                    0                0
# ...

# %%
data.country.nunique()
# Out:
# 193

# %%
data2=data.drop('country',axis=1)

# %%
data2
# Out:
#      beer_servings  spirit_servings  wine_servings  \
# 0              0.0              0.0            0.0
# 1             89.0            132.0           54.0
# 2             25.0              0.0           14.0
# 3            245.0            138.0          312.0
# 4            217.0             57.0           45.0
# ..             ...              ...            ...
# 188           76.0            100.0            3.0
# 189          111.0              2.0            1.0
# 190            6.0              0.0            0.0
# 191           32.0             19.0            4.0
# 192           64.0             18.0            4.0
#
#      total_litres_of_pure_alcohol  continent
# 0                             0.0          1
# 1                             4.9          2
# 2                             0.7          0
# 3                            12.4          2
# 4                             5.9          0
# ..                            ...        ...
# ...

# %%
data2.shape
# Out:
# (193, 5)

# %%
data2=pd.get_dummies(data2)

# %%
data2.shape
# Out:
# (193, 10)

# %%
data2
# Out:
#      beer_servings  spirit_servings  wine_servings  \
# 0              0.0              0.0            0.0
# 1             89.0            132.0           54.0
# 2             25.0              0.0           14.0
# 3            245.0            138.0          312.0
# 4            217.0             57.0           45.0
# ..             ...              ...            ...
# 188           76.0            100.0            3.0
# 189          111.0              2.0            1.0
# 190            6.0              0.0            0.0
# 191           32.0             19.0            4.0
# 192           64.0             18.0            4.0
#
#      total_litres_of_pure_alcohol  continent_Africa  continent_Asia  \
# 0                             0.0                 0               1
# 1                             4.9                 0               0
# 2                             0.7                 1               0
# 3                            12.4                 0               0
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
label_encoder=LabelEncoder()

# %%
data['continent']=label_encoder.fit_transform(data['continent'])

# %%
data.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan            0.0              0.0            0.0
# 1      Albania           89.0            132.0           54.0
# 2      Algeria           25.0              0.0           14.0
# 3      Andorra          245.0            138.0          312.0
# 4       Angola          217.0             57.0           45.0
#
#    total_litres_of_pure_alcohol  continent
# 0                           0.0          1
# 1                           4.9          2
# 2                           0.7          0
# 3                          12.4          2
# 4                           5.9          0

# %%
X=data2.drop('total_litres_of_pure_alcohol',axis=1)
y=data2['total_litres_of_pure_alcohol']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=42,test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()
model = lr.fit(X_train,y_train)
predictions=model.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error,r2_score

# %%
print('Mean Squared Error is: ',mean_squared_error(y_test,predictions))
print('R Squared value is: ',r2_score(y_test,predictions))
# Out:
# Mean Squared Error is:  1.7720922847547185
# R Squared value is:  0.916337574413759

# %%
X.describe()
# Out:
#        beer_servings  spirit_servings  wine_servings   continent
# count     193.000000       193.000000      193.00000  193.000000
# mean      103.917098        82.259067       48.88601    1.694301
# std        98.580146        87.389366       79.41700    1.501672
# min         0.000000         0.000000        0.00000    0.000000
# 25%        21.000000         5.000000        1.00000    0.000000
# 50%        76.000000        60.000000        9.00000    1.000000
# 75%       171.000000       128.000000       59.00000    3.000000
# max       376.000000       438.000000      370.00000    5.000000

# %%
X1=X.drop('continent',axis=1)

# %%
X1.head()
# Out:
#    beer_servings  spirit_servings  wine_servings
# 0            0.0              0.0            0.0
# 1           89.0            132.0           54.0
# 2           25.0              0.0           14.0
# 3          245.0            138.0          312.0
# 4          217.0             57.0           45.0

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
min_max_scaler=MinMaxScaler(feature_range=(0,1))

# %%
x1=min_max_scaler.fit_transform(X1)

# %%
type(x1)
# Out:
# numpy.ndarray

# %%
data.columns
# Out:
# Index(['country', 'beer_servings', 'spirit_servings', 'wine_servings',
#        'total_litres_of_pure_alcohol', 'continent'],
#       dtype='object')

# %%
x1=pd.DataFrame(x1,columns=['beer_servings','spirit_servings','wine_servings'])

# %%
x1.describe()
# Out:
#        beer_servings  spirit_servings  wine_servings
# count     193.000000       193.000000     193.000000
# mean        0.276375         0.187806       0.132124
# std         0.262181         0.199519       0.214641
# min         0.000000         0.000000       0.000000
# 25%         0.055851         0.011416       0.002703
# 50%         0.202128         0.136986       0.024324
# 75%         0.454787         0.292237       0.159459
# max         1.000000         1.000000       1.000000

# %%
type(x1)
# Out:
# pandas.core.frame.DataFrame

# %%
x1.drop(['beer_servings','spirit_servings','wine_servings'],axis=1,inplace=True)

# %%
X=pd.concat([X,x1],axis=1)

# %%
X.head()
# Out:
#    beer_servings  spirit_servings  wine_servings  continent
# 0            0.0              0.0            0.0          1
# 1           89.0            132.0           54.0          2
# 2           25.0              0.0           14.0          0
# 3          245.0            138.0          312.0          2
# 4          217.0             57.0           45.0          0

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=42,test_size=.20)

# %%
X.head()
# Out:
#    beer_servings  spirit_servings  wine_servings  continent
# 0            0.0              0.0            0.0          1
# 1           89.0            132.0           54.0          2
# 2           25.0              0.0           14.0          0
# 3          245.0            138.0          312.0          2
# 4          217.0             57.0           45.0          0

# %%
X.tail()
# Out:
#      beer_servings  spirit_servings  wine_servings  continent
# 188           76.0            100.0            3.0          5
# 189          111.0              2.0            1.0          1
# 190            6.0              0.0            0.0          1
# 191           32.0             19.0            4.0          0
# 192           64.0             18.0            4.0          0

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=42,test_size=.20)

# %%
lr=LinearRegression()
model=lr.fit(X_train,y_train)
predictions=model.predict(X_test)

# %%
print('Mean Squared Error is: ',mean_squared_error(y_test,predictions))
print('R Squared value is: ',r2_score(y_test,predictions))
# Out:
# Mean Squared Error is:  1.7720922847547185
# R Squared value is:  0.916337574413759

# %%
X = data2.drop('total_litres_of_pure_alcohol',axis=1)
y =data2['total_litres_of_pure_alcohol']

# %%
X.describe()
# Out:
#        beer_servings  spirit_servings  wine_servings   continent
# count     193.000000       193.000000      193.00000  193.000000
# mean      103.917098        82.259067       48.88601    1.694301
# std        98.580146        87.389366       79.41700    1.501672
# min         0.000000         0.000000        0.00000    0.000000
# 25%        21.000000         5.000000        1.00000    0.000000
# 50%        76.000000        60.000000        9.00000    1.000000
# 75%       171.000000       128.000000       59.00000    3.000000
# max       376.000000       438.000000      370.00000    5.000000

# %%
from sklearn.preprocessing import StandardScaler

# %%
std_scl = StandardScaler()

# %%
X1 = X.drop('continent', axis=1)

# %%
x1 = std_scl.fit_transform(X1)

# %%
type(X1)
# Out:
# pandas.core.frame.DataFrame

# %%
X1 = pd.DataFrame(X1, columns=['beer_servings','spirit_servings','wine_servings'])

# %%
X.drop(['beer_servings','spirit_servings','wine_servings'],axis=1,inplace=True)

# %%
X=pd.concat([X,X1],axis=1)

# %%
X.head()
# Out:
#    continent  beer_servings  spirit_servings  wine_servings
# 0          1            0.0              0.0            0.0
# 1          2           89.0            132.0           54.0
# 2          0           25.0              0.0           14.0
# 3          2          245.0            138.0          312.0
# 4          0          217.0             57.0           45.0

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y, random_state=42,test_size=20)

# %%
lr=LinearRegression()
model = lr.fit(X_train,y_train)
predictions=model.predict(X_test)

# %%
data=pd.read_csv(r'/content/sample_data/Social network Ads.csv')

# %%
data
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 1    15810944    Male   35            20000          0
# 2    15668575  Female   26            43000          0
# 3    15603246  Female   27            57000          0
# 4    15804002    Male   19            76000          0
# ..        ...     ...  ...              ...        ...
# 395  15691863  Female   46            41000          1
# 396  15706071    Male   51            23000          1
# 397  15654296  Female   50            20000          1
# 398  15755018    Male   36            33000          0
# 399  15594041  Female   49            36000          1
#
# [400 rows x 5 columns]

# %%
data.isna().sum()
# Out:
# User ID            0
# Gender             0
# Age                0
# EstimatedSalary    0
# Purchased          0
# dtype: int64

# %%
data.shape
# Out:
# (400, 5)

# %%
data.dtypes
# Out:
# User ID             int64
# Gender             object
# Age                 int64
# EstimatedSalary     int64
# Purchased           int64
# dtype: object

# %%
data2=data.drop('Gender',axis=1)

# %%
data2
# Out:
#       User ID  Age  EstimatedSalary  Purchased
# 0    15624510   19            19000          0
# 1    15810944   35            20000          0
# 2    15668575   26            43000          0
# 3    15603246   27            57000          0
# 4    15804002   19            76000          0
# ..        ...  ...              ...        ...
# 395  15691863   46            41000          1
# 396  15706071   51            23000          1
# 397  15654296   50            20000          1
# 398  15755018   36            33000          0
# 399  15594041   49            36000          1
#
# [400 rows x 4 columns]

# %%
data2.shape
# Out:
# (400, 4)
